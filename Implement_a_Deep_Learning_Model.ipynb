# %% [markdown]
# <a href="https://colab.research.google.com/github/waqarch-tech/YoungDevInterns_Artificial-Intelligence_Tasks/blob/main/Implement_a_Deep_Learning_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
import pandas as pd
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# 1. LOAD DATA
print("Loading data...")
path = kagglehub.dataset_download("mukundsavaliya/california-housing-data")
csv_file = [f for f in os.listdir(path) if f.endswith('.csv')][0]
df = pd.read_csv(os.path.join(path, csv_file))

# 2. PREPROCESS (Creating X_scaled and y_class)
print("Preprocessing...")
df_encoded = pd.get_dummies(df)
imputer = SimpleImputer(strategy='median')
df_imputed = pd.DataFrame(imputer.fit_transform(df_encoded), columns=df_encoded.columns)

# Define X (features)
X = df_imputed.drop('median_house_value', axis=1)

# Define y_class (target) - 1 if above median price, else 0
y_class = (df_imputed['median_house_value'] > df_imputed['median_house_value'].median()).astype(int)

# Scale the data (This creates X_scaled)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. SPLIT DATA (This creates X_train, y_train, etc.)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_class, test_size=0.2, random_state=42)

print("SUCCESS: X_train and y_train are now defined and ready!")
# Out:
# Loading data...
# Using Colab cache for faster access to the 'california-housing-data' dataset.
# Preprocessing...
# SUCCESS: X_train and y_train are now defined and ready!

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# BUILD THE MODEL
model = models.Sequential([
    # Input layer + First Hidden Layer
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.BatchNormalization(), # Detail: Batch Normalization
    layers.Dropout(0.3),         # Detail: Dropout (prevents overfitting)

    # Second Hidden Layer
    layers.Dense(32, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    # Output layer (Sigmoid for binary classification)
    layers.Dense(1, activation='sigmoid')
])

# COMPILE
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# TRAIN
print("Training model...")
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=1)

# EVALUATE
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nFinal Deep Learning Accuracy: {accuracy:.4f}")
# Out:
# Training model...
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6057 - loss: 0.7401 - val_accuracy: 0.7625 - val_loss: 0.5958
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7458 - loss: 0.5362 - val_accuracy: 0.8042 - val_loss: 0.5357
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7812 - loss: 0.4645 - val_accuracy: 0.8021 - val_loss: 0.4907
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7891 - loss: 0.4584 - val_accuracy: 0.8125 - val_loss: 0.4602
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8073 - loss: 0.4216 - val_accuracy: 0.8167 - val_loss: 0.4347
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8224 - loss: 0.4036 - val_accuracy: 0.8125 - val_loss: 0.4179
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8229 - loss: 0.4016 - val_accuracy: 0.8313 - val_loss: 0.4046
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8286 - loss: 0.3912 - val_accuracy: 0.8333 - val_loss: 0.4042
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8333 - loss: 0.3736 - val_accuracy: 0.8229 - val_loss: 0.4030
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8344 - loss: 0.3735 - val_accuracy: 0.8250 - val_loss: 0.3988
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8464 - loss: 0.3602 - val_accuracy: 0.8208 - val_loss: 0.4039
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8328 - loss: 0.3862 - val_accuracy: 0.8375 - val_loss: 0.4004
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8406 - loss: 0.3647 - val_accuracy: 0.8313 - val_loss: 0.4032
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8313 - loss: 0.3725 - val_accuracy: 0.8292 - val_loss: 0.3981
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8396 - loss: 0.3615 - val_accuracy: 0.8417 - val_loss: 0.4002
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8333 - loss: 0.3665 - val_accuracy: 0.8313 - val_loss: 0.4004
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8370 - loss: 0.3513 - val_accuracy: 0.8396 - val_loss: 0.4015
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8391 - loss: 0.3545 - val_accuracy: 0.8271 - val_loss: 0.3981
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8458 - loss: 0.3502 - val_accuracy: 0.8313 - val_loss: 0.3944
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8484 - loss: 0.3505 - val_accuracy: 0.8313 - val_loss: 0.3893
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8383 - loss: 0.3559
#
# Final Deep Learning Accuracy: 0.8383
