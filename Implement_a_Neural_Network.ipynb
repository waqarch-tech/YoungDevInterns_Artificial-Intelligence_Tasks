# %% [markdown]
# <a href="https://colab.research.google.com/github/waqarch-tech/YoungDevInterns_Artificial-Intelligence_Tasks/blob/main/Implement_a_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# 1. Define a Simple Neural Network (The 'Brain' behind your webpage)
model = models.Sequential([
    layers.Dense(8, activation='relu', input_shape=(4,)), # Input: 4 flower measurements
    layers.Dense(3, activation='softmax')               # Output: 3 flower types
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 2. Print Summary to show 'Implementation'
print("Neural Network successfully implemented for the Webpage Backend:")
model.summary()
# Out:
# Neural Network successfully implemented for the Webpage Backend:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 67 (268.00 B)
#  Trainable params: 67 (268.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model for 50 rounds (epochs)
history = model.fit(X_train, y_train, epochs=50, batch_size=5, verbose=1)

# Verify performance
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\n✅ Final Task 1 Accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3250 - loss: 1.9066
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3250 - loss: 1.6681
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3250 - loss: 1.4650
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3250 - loss: 1.2705
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3250 - loss: 1.0894
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3750 - loss: 0.9553
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6833 - loss: 0.8809
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.8247
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.7871
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8083 - loss: 0.7478
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.7187
# Epoch 12/50
# ...

# %%
import matplotlib.pyplot as plt

# Visualize the training progress
plt.plot(history.history['accuracy'], label='Accuracy', color='green')
plt.plot(history.history['loss'], label='Loss', color='red')
plt.title('Task 1: Training Progress')
plt.xlabel('Epochs')
plt.legend()
plt.show()
